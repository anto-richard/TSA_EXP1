# %% [markdown]
# <a href="https://colab.research.google.com/github/anto-richard/TSA_EXP1/blob/main/Timeseries_1T.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("ClimateTrain.csv",parse_dates=["date"],index_col="date")

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df["2017-01"]
# Out:
# <ipython-input-4-7bfadbc7a979>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017-01"]
#             meantemp  humidity  wind_speed  meanpressure
# date
# 2017-01-01      10.0     100.0         0.0        1016.0

# %%
df["2017"].mean()
# Out:
# <ipython-input-5-529b08a1788f>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017"].mean()
# meantemp          10.0
# humidity         100.0
# wind_speed         0.0
# meanpressure    1016.0
# dtype: float64

# %%
df["2017-05-01":"2015-08-31"]
# Out:
# Empty DataFrame
# Columns: [meantemp, humidity, wind_speed, meanpressure]
# Index: []

# %%
df['meantemp'].resample('M').mean()
# Out:
# date
# 2013-01-31    12.074770
# 2013-02-28    16.867560
# 2013-03-31    22.814209
# 2013-04-30    28.895119
# 2013-05-31    33.776767
# 2013-06-30    32.480873
# 2013-07-31    30.663594
# 2013-08-31    29.547773
# 2013-09-30    29.840595
# 2013-10-31    26.129186
# 2013-11-30    18.811706
# 2013-12-31    15.179339
# 2014-01-31    13.431836
# 2014-02-28    15.746811
# 2014-03-31    21.593318
# 2014-04-30    28.058333
# 2014-05-31    31.405530
# 2014-06-30    34.770833
# 2014-07-31    32.034163
# 2014-08-31    31.411968
# 2014-09-30    29.762500
# 2014-10-31    26.496544
# 2014-11-30    20.104167
# 2014-12-31    14.823733
# 2015-01-31    12.708525
# 2015-02-28    18.791454
# 2015-03-31    21.547811
# 2015-04-30    28.002976
# 2015-05-31    33.352535
# 2015-06-30    32.737500
# 2015-07-31    30.409562
# 2015-08-31    30.330789
# 2015-09-30    30.650000
# 2015-10-31    26.865207
# 2015-11-30    20.754167
# 2015-12-31    14.989631
# 2016-01-31    15.139363
# 2016-02-29    19.025676
# ...

# %%
mean=df["meantemp"].resample('M').mean().plot(kind='line')
plt.xlabel("Month")
plt.ylabel("Temperature")
plt.show()

# %%
mean=df["meantemp"].resample('Y').mean().plot(kind='line')
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.show()
