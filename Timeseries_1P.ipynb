# %% [markdown]
# <a href="https://colab.research.google.com/github/anto-richard/TSA_EXP1/blob/main/Timeseries_1P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dataset: https://fred.stlouisfed.org/series/POPTHM

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("POPTHM.csv",parse_dates=["DATE"],index_col="DATE")

# %%
df.head()
# Out:
#               POPTHM
# DATE
# 1959-01-01  175818.0
# 1959-02-01  176044.0
# 1959-03-01  176274.0
# 1959-04-01  176503.0
# 1959-05-01  176723.0

# %%
df["2017-01"]
# Out:
# <ipython-input-6-7bfadbc7a979>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017-01"]
#               POPTHM
# DATE
# 2017-01-01  325901.0

# %%
df["2017"].mean()
# Out:
# <ipython-input-8-529b08a1788f>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017"].mean()
# POPTHM    326859.666667
# dtype: float64

# %%
df["2017-05":"2017-06"]
# Out:
#               POPTHM
# DATE
# 2017-05-01  326548.0
# 2017-06-01  326743.0

# %%
df.resample('Y').mean()
# Out:
#                    POPTHM
# DATE
# 1959-12-31  177130.083333
# 1960-12-31  180760.166667
# 1961-12-31  183742.250000
# 1962-12-31  186590.500000
# 1963-12-31  189299.583333
# ...                   ...
# 2019-12-31  330512.583333
# 2020-12-31  331799.833333
# 2021-12-31  332367.333333
# 2022-12-31  333568.333333
# 2023-12-31  335208.416667
#
# [65 rows x 1 columns]

# %%
mean=df.resample('Y').mean().plot(kind='line')
plt.xlabel("Year")
plt.ylabel("Population(in Thousands)")
plt.show()
